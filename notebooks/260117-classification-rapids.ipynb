# %%
# %load_ext cudf.pandas
import cudf, cugraph
from cuml.cluster import KMeans
import sys
from pathlib import Path
sys.path.append(str(Path("..").resolve()))
from db.database import Database
from util.dataframe_utils import get_dataframes
db = Database()

# %%
pd_bp_df, pd_topics_df, pd_posts_df = get_dataframes(db)
bp_df = cudf.from_pandas(pd_bp_df)
topics_df = cudf.from_pandas(pd_topics_df)
posts_df = cudf.from_pandas(pd_posts_df)
bp_df
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:3084, in as_column(arbitrary, nan_as_null, dtype, length)
#    3083 try:
# -> 3084     pyarrow_array = pa.array(arbitrary, from_pandas=False)
#    3085 except (pa.lib.ArrowInvalid, pa.lib.ArrowTypeError):
#    3086     # Decimal can hold float("nan")
#    3087     # All np.nan is not restricted by type
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/array.pxi:365, in pyarrow.lib.array()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/array.pxi:91, in pyarrow.lib._ndarray_to_array()
#
# File ~/.local/lib/python3.10/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Could not convert <sqlalchemy.orm.state.InstanceState object at 0x7fa1fb251480> with type InstanceState: did not recognize Python value type when inferring an Arrow data type
#
# During handling of the above exception, another exception occurred:
#
# MixedTypeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 pd_bp_df, pd_topics_df, pd_posts_df = get_dataframes(db)
#       2 bp_df = cudf.from_pandas(pd_bp_df)
# ----> 3 topics_df = cudf.from_pandas(pd_topics_df)
#       4 posts_df = cudf.from_pandas(pd_posts_df)
#
# File ~/.local/lib/python3.10/site-packages/cudf/pandas/_wrappers/pandas.py:2241, in wrap_from_pandas.<locals>.wrapped_from_pandas(obj, *args, **kwargs)
#    2238 @functools.wraps(original_call)
#    2239 def wrapped_from_pandas(obj, *args, **kwargs):
#    2240     if is_proxy_object(obj):
# -> 2241         obj = obj.as_gpu_object()
#    2242         return obj
#    2243     return original_call(obj, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:210, in make_final_proxy_type.<locals>.as_gpu_object(self)
#     209 def as_gpu_object(self):
# --> 210     return self._fsproxy_slow_to_fast()
#
# File ~/.local/lib/python3.10/site-packages/cudf/pandas/fast_slow_proxy.py:194, in make_final_proxy_type.<locals>._fsproxy_slow_to_fast(self)
#     185 @nvtx.annotate(
#     186     "COPY_SLOW_TO_FAST",
#     187     color=_CUDF_PANDAS_NVTX_COLORS["COPY_SLOW_TO_FAST"],
#    (...)
#     191     # if we are wrapping a slow object,
#     192     # convert it to a fast one
#     193     if self._fsproxy_state is _State.SLOW:
# --> 194         return slow_to_fast(self._fsproxy_wrapped)
#     195     return self._fsproxy_wrapped
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:8751, in from_pandas(obj, nan_as_null)
#    8748     nan_as_null = False if get_option("mode.pandas_compatible") else None
#    8750 if isinstance(obj, pd.DataFrame):
# -> 8751     return DataFrame(obj, nan_as_null=nan_as_null)
#    8752 elif isinstance(obj, pd.Series):
#    8753     return Series(obj, nan_as_null=nan_as_null)
#
# File ~/.local/lib/python3.10/site-packages/cudf/pandas/_wrappers/pandas.py:2319, in DataFrame_init_(self, data, index, columns, *args, **kwargs)
#    2317     self.__dict__.update(data.__dict__)
#    2318     return
# -> 2319 _original_DataFrame_init(self, data, index, columns, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:993, in DataFrame.__init__(self, data, index, columns, dtype, copy, nan_as_null)
#     991 attrs = deepcopy(data.attrs)
#     992 if isinstance(data, pd.DataFrame):
# --> 993     cols = {
#     994         i: as_column(col_value.array, nan_as_null=nan_as_null)
#     995         for i, (_, col_value) in enumerate(data.items())
#     996     }
#     997     new_idx = from_pandas(data.index, nan_as_null=nan_as_null)
#     998     df = type(self)._from_data(cols, new_idx)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/dataframe.py:994, in <dictcomp>(.0)
#     991 attrs = deepcopy(data.attrs)
#     992 if isinstance(data, pd.DataFrame):
#     993     cols = {
# --> 994         i: as_column(col_value.array, nan_as_null=nan_as_null)
#     995         for i, (_, col_value) in enumerate(data.items())
#     996     }
#     997     new_idx = from_pandas(data.index, nan_as_null=nan_as_null)
#     998     df = type(self)._from_data(cols, new_idx)
#
# File ~/.local/lib/python3.10/site-packages/cudf/core/column/column.py:3088, in as_column(arbitrary, nan_as_null, dtype, length)
#    3084         pyarrow_array = pa.array(arbitrary, from_pandas=False)
#    3085     except (pa.lib.ArrowInvalid, pa.lib.ArrowTypeError):
#    3086         # Decimal can hold float("nan")
#    3087         # All np.nan is not restricted by type
# -> 3088         raise MixedTypeError(
#    3089             f"Cannot have NaN with {inferred_dtype}"
#    3090         )
#    3092 if pyarrow_array is None:
#    3093     pyarrow_array = pa.array(
#    3094         arbitrary,
#    3095         from_pandas=True,
#    3096     )
#
# MixedTypeError: Cannot have NaN with mixed

# %%
import json, re
def process_bp_keywords(kwd_dict: dict[str, int] | str) -> list[str] | None:
    if isinstance(kwd_dict, str):
        kwd_dict = json.loads(kwd_dict)
    
    kwd_list = list(kwd_dict.keys())
    if kwd_list.__len__() < 1:
        return None
    
    kwds = []
    
    for kwd in kwd_list:
        in_out = re.search(r"(input__|output__)(input_|output_)?", kwd)
        kwd = kwd.removeprefix(in_out.group()) if in_out else kwd
        in_out = in_out.group(1) if in_out else None
        kwds.append(in_out + kwd if in_out else kwd)
    return kwds

# %%
ignorable_tags = {"blueprint", "automation"}
bp_df["tags"] = bp_df["tags"].apply(lambda tags: [tag for tag in json.loads(tags) if tag not in ignorable_tags])
bp_df.head()
# Out:
#                                        blueprint_url  \
# 0  https://community.home-assistant.io//t/nag-pro...
# 1  https://community.home-assistant.io//t/inovell...
# 2  https://community.home-assistant.io//t/deconz-...
# 3  https://community.home-assistant.io//t/set-hea...
# 4  https://community.home-assistant.io//t/light-a...
#
#                                       blueprint_code  post_id  \
# 0  blueprint:\n  name: Nag prompt blueprint\n  de...  1220860
# 1  blueprint:\n  name: Inovelli \n  description: ...  1220678
# 2  blueprint:\n  name: deCONZ - IKEA five button ...  1223455
# 3  blueprint:\n  name: Heat for certain time\n  d...  1223628
# 4  blueprint:\n  name: Light Allowance\n  descrip...  1224871
#
#                                          description  \
# 0                Nag a mobile device to do something
# 1  Use this blueprint to create automations based...
# 2   Control anything using IKEA five button remote\n
# 3        Turn on heating for a given amount of time.
# 4           Turns a light off after an allotted time
#
#                                       topic_keywords  \
# 0  {"android": 0.04282333988128355, "user": 0.042...
# 1  {"inovelli": 0.027025502281732554, "create": 0...
# 2  {"short": 0.01649244354775234, "long": 0.01649...
# 3  {"set": 0.055741499059047184, "temperature": 0...
# 4  {"time": 0.11369206228658875, "light": 0.13453...
#
#                                       keywords_tfidf  id  \
# 0  {"nag": 0.6591492709484212, "prompt": 0.237436...   1
# 1  {"inovelli": 0.49285018857218027, "lzw36": 0.4...   2
# 2  {"button": 0.4699242472830788, "five": 0.35503...   3
# 3  {"heat": 0.34881772060990424, "heating": 0.334...   4
# 4  {"allotted": 0.6327468890387052, "allowance": ...   5
#
#                                       blueprint_hash  \
# 0  2f523787adf856fbddd08b2f7b32aa2490eb48a236bc68...
# 1  ca6a74b04fac9cee0925adfe7cb03c8beb0354a816fa66...
# 2  c5f67655e23dff66b1042d3b38e967d74dad01a4a3d589...
# 3  00b1c4d2e847ed9451c8e8d1acfbbcd5e1740f9991226d...
# 4  0dd0ec70d42f2e8a428ae7a2934852dbec0beb34cd03cc...
#
#                                name  \
# 0              Nag prompt blueprint
# 1                          Inovelli
# 2  deCONZ - IKEA five button remote
# 3             Heat for certain time
# 4                   Light Allowance
#
#                                   extracted_keywords  \
# 0                        {"input__input_boolean": 2}
# 1                                                 {}
# 2                               {"input__deconz": 1}
# 3  {"input__input_datetime": 1, "input__climate": 2}
# 4            {"input__light": 1, "output__light": 1}
#
#                                        keywords_yake  \
# 0  ["android notification", "nag prompt", "nag no...
# 1            ["fan", "inovelli", "create", "dimmer"]
# 2  ["button short", "button remote", "long press"...
# 3  ["set heating", "heating temperature", "time",...
# 4  ["light allowance", "light", "allowance", "all...
#
#                                          topic_title topic_id  \
# 0        Nag prompt Blueprint (Android Notification)   255041
# 1                   Inovelli LZW36 Fan/Dimmer Scenes   254999
# 2                   deCONZ - IKEA five button remote   255699
# 3  Set heating temperature to a configurable valu...   255742
# 4                                    Light Allowance   256045
#
#                tags              created_at  \
# 0                [] 2020-12-14 01:40:32.358
# 1                [] 2020-12-13 22:32:38.158
# 2  [switch, deconz] 2020-12-15 12:18:15.898
# 3                [] 2020-12-15 14:23:53.414
# 4                [] 2020-12-16 04:23:36.519
#
#                                         post_content       processed_keywords
# 0  <p>This blueprints creates configurable nag no...              ["boolean"]
# 1  <p>This blueprint allows you to easily create ...                     null
# 2  <p>This is a mix of <a href="https://community...               ["deconz"]
# 3  <p>This is a blueprint, that allows to set the...  ["datetime", "climate"]
# 4  <p>This blueprint will turn a light off after ...       ["light", "light"]

# %%
max_keywords = bp_df["extracted_keywords"].apply(lambda x: len(json.loads(x)) if isinstance(x, str) else 0).max() 
max_tags = bp_df["tags"].apply(lambda x: len(x) if isinstance(x, list) else 0).max()
max_yake = 4
max_features = max_keywords + max_tags + max_yake
max_keywords, max_tags, max_features
# Out:
# (np.int64(15), np.int64(5), np.int64(24))

# %%
def extract_features(row, max_features=max_features):
    padding = "<PAD>"
    
    yake_features = json.loads(row["keywords_yake"])
    combined_features = list(yake_features)
    ext_kw = process_bp_keywords(row["extracted_keywords"])
    if ext_kw:
        combined_features.extend(ext_kw)
    
    kw_n = max_keywords - len(ext_kw) if ext_kw else max_keywords
    combined_features += [padding] * kw_n
    
    tags = row["tags"]
    tag_n = max_tags - len(tags)
    combined_features.extend(tags)
    combined_features += [padding] * tag_n

    return combined_features

# %%
bp_df["features"] = bp_df.apply(extract_features, axis=1)
bp_df.head()
# Out:
#                                        blueprint_url  \
# 0  https://community.home-assistant.io//t/nag-pro...
# 1  https://community.home-assistant.io//t/inovell...
# 2  https://community.home-assistant.io//t/deconz-...
# 3  https://community.home-assistant.io//t/set-hea...
# 4  https://community.home-assistant.io//t/light-a...
#
#                                       blueprint_code  post_id  \
# 0  blueprint:\n  name: Nag prompt blueprint\n  de...  1220860
# 1  blueprint:\n  name: Inovelli \n  description: ...  1220678
# 2  blueprint:\n  name: deCONZ - IKEA five button ...  1223455
# 3  blueprint:\n  name: Heat for certain time\n  d...  1223628
# 4  blueprint:\n  name: Light Allowance\n  descrip...  1224871
#
#                                          description  \
# 0                Nag a mobile device to do something
# 1  Use this blueprint to create automations based...
# 2   Control anything using IKEA five button remote\n
# 3        Turn on heating for a given amount of time.
# 4           Turns a light off after an allotted time
#
#                                       topic_keywords  \
# 0  {"android": 0.04282333988128355, "user": 0.042...
# 1  {"inovelli": 0.027025502281732554, "create": 0...
# 2  {"short": 0.01649244354775234, "long": 0.01649...
# 3  {"set": 0.055741499059047184, "temperature": 0...
# 4  {"time": 0.11369206228658875, "light": 0.13453...
#
#                                       keywords_tfidf  id  \
# 0  {"nag": 0.6591492709484212, "prompt": 0.237436...   1
# 1  {"inovelli": 0.49285018857218027, "lzw36": 0.4...   2
# 2  {"button": 0.4699242472830788, "five": 0.35503...   3
# 3  {"heat": 0.34881772060990424, "heating": 0.334...   4
# 4  {"allotted": 0.6327468890387052, "allowance": ...   5
#
#                                       blueprint_hash  \
# 0  2f523787adf856fbddd08b2f7b32aa2490eb48a236bc68...
# 1  ca6a74b04fac9cee0925adfe7cb03c8beb0354a816fa66...
# 2  c5f67655e23dff66b1042d3b38e967d74dad01a4a3d589...
# 3  00b1c4d2e847ed9451c8e8d1acfbbcd5e1740f9991226d...
# 4  0dd0ec70d42f2e8a428ae7a2934852dbec0beb34cd03cc...
#
#                                name  \
# 0              Nag prompt blueprint
# 1                          Inovelli
# 2  deCONZ - IKEA five button remote
# 3             Heat for certain time
# 4                   Light Allowance
#
#                                   extracted_keywords  \
# 0                        {"input__input_boolean": 2}
# 1                                                 {}
# 2                               {"input__deconz": 1}
# 3  {"input__input_datetime": 1, "input__climate": 2}
# 4            {"input__light": 1, "output__light": 1}
#
#                                        keywords_yake  \
# 0  ["android notification", "nag prompt", "nag no...
# 1            ["fan", "inovelli", "create", "dimmer"]
# 2  ["button short", "button remote", "long press"...
# 3  ["set heating", "heating temperature", "time",...
# 4  ["light allowance", "light", "allowance", "all...
#
#                                          topic_title topic_id  \
# 0        Nag prompt Blueprint (Android Notification)   255041
# 1                   Inovelli LZW36 Fan/Dimmer Scenes   254999
# 2                   deCONZ - IKEA five button remote   255699
# 3  Set heating temperature to a configurable valu...   255742
# 4                                    Light Allowance   256045
#
#                tags              created_at  \
# 0                [] 2020-12-14 01:40:32.358
# 1                [] 2020-12-13 22:32:38.158
# 2  [switch, deconz] 2020-12-15 12:18:15.898
# 3                [] 2020-12-15 14:23:53.414
# 4                [] 2020-12-16 04:23:36.519
#
#                                         post_content       processed_keywords  \
# 0  <p>This blueprints creates configurable nag no...              ["boolean"]
# 1  <p>This blueprint allows you to easily create ...                     null
# 2  <p>This is a mix of <a href="https://community...               ["deconz"]
# 3  <p>This is a blueprint, that allows to set the...  ["datetime", "climate"]
# 4  <p>This blueprint will turn a light off after ...       ["light", "light"]
#
#                                             features
# 0  [android notification, nag prompt, nag notific...
# 1  [fan, inovelli, create, dimmer, <PAD>, <PAD>, ...
# 2  [button short, button remote, long press, butt...
# 3  [set heating, heating temperature, time, set, ...
# 4  [light allowance, light, allowance, allotted, ...

# %%
sent_model
